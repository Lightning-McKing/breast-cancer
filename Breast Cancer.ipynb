# %%
import pandas as pd
import cv2
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:/Datasets/bc.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
y=df["diagnosis"]

# %%
df=df.drop("Unnamed: 32",axis="columns")
df=df.drop("id",axis="columns")

# %%
y=pd.get_dummies(y)

# %%
x=df.drop("diagnosis",axis="columns")

# %%
x.shape
# Out:
# (569, 30)

# %%
y.shape
# Out:
# (569, 2)

# %%
sns.heatmap(df.corr(),xticklabels=df.columns,yticklabels=df.columns)
plt.show()

# %%
from keras.utils import to_categorical

# %%
y=to_categorical(y)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(128,activation="relu",input_shape=(30,)))
model.add(Dense(64,activation="relu"))
model.add(Dense(64,activation="relu"))
model.add(Dense(2,activation="softmax"))

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(x,y,epochs=1000)
# Out:
# Epoch 1/1000
# 18/18 [==============================] - 0s 522us/step - loss: 0.1471 - accuracy: 0.9367
# Epoch 2/1000
# 18/18 [==============================] - 0s 554us/step - loss: 0.1368 - accuracy: 0.9473
# Epoch 3/1000
# 18/18 [==============================] - 0s 610us/step - loss: 0.1456 - accuracy: 0.9402
# Epoch 4/1000
# 18/18 [==============================] - 0s 609us/step - loss: 0.2480 - accuracy: 0.9069
# Epoch 5/1000
# 18/18 [==============================] - 0s 720us/step - loss: 0.1833 - accuracy: 0.9315
# Epoch 6/1000
# 18/18 [==============================] - 0s 720us/step - loss: 0.1652 - accuracy: 0.9332
# Epoch 7/1000
# 18/18 [==============================] - 0s 554us/step - loss: 0.2057 - accuracy: 0.9315
# Epoch 8/1000
# 18/18 [==============================] - 0s 665us/step - loss: 0.1424 - accuracy: 0.9385
# Epoch 9/1000
# 18/18 [==============================] - 0s 609us/step - loss: 0.1329 - accuracy: 0.9455
# Epoch 10/1000
# ...

# %%
data=pd.DataFrame({"radius_mean":[20.9],"texture_mean":[11.3],"perimeter_mean":[100.4],"area_mean":[1128.7],"smoothness_mean":[0.233],"compactness_mean":[0.4534],""})
